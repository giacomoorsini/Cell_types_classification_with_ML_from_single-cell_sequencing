# %% [markdown]
# <a href="https://colab.research.google.com/github/giacomoorsini/single_cell-ML_project/blob/main/single_cell-ML_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cell type recognition from single cell sequencing data in Mus musculus

# %% [markdown]
# Tabula Muris is a compendium of single cell transcriptome data from the model organism Mus musculus, containing nearly 100,000 cells from 20 organs and tissues.

# %% [markdown]
# - Data retrieval
# - Data pre processing
# - Model building
# - Result evaluation

# %% [markdown]
# # Data retrieval

# %%
# !wget https://figshare.com/ndownloader/files/10700143
# Out:
# --2024-05-12 15:40:44--  https://figshare.com/ndownloader/files/10700143
# Resolving figshare.com (figshare.com)... 52.214.121.144, 34.248.40.228, 2a05:d018:1f4:d000:3f19:fbeb:425e:effb, ...
# Connecting to figshare.com (figshare.com)|52.214.121.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/10700143/FACS.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20240512/eu-west-1/s3/aws4_request&X-Amz-Date=20240512T154044Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=71ae72e37e113c94f8b00d60f649761c6728eda1a0ab628c9e37464b7606a56d [following]
# ...

# %%
# !unzip 10700143

# %%
# !mkdir heart_data

# %%
# !mv FACS/Heart-counts.csv heart_data

# %%
import pandas as pd

# %%
# create metadata dataframe
metadata=pd.read_csv("/content/metadata_FACS.csv")
metadata.head(10)
# Out:
#     plate.barcode mouse.id   tissue subtissue FACS.selection mouse.sex
# 0         D041914    3_8_M  Bladder       NaN       Multiple         M
# 1         D042253    3_9_M  Bladder       NaN       Multiple         M
# 2       MAA000487   3_10_M  Bladder       NaN       Multiple         M
# 3         B000610   3_56_F  Bladder       NaN       Multiple         F
# 4         B002764   3_38_F  Bladder       NaN       Multiple         F
# ..            ...      ...      ...       ...            ...       ...
# 242       D042474    3_8_M  Trachea       NaN       Multiple         M
# 243       D042475    3_9_M  Trachea       NaN       Multiple         M
# 244     MAA000496   3_10_M  Trachea       NaN       Multiple         M
# 245     MAA001865   3_38_F  Trachea       NaN       Multiple         F
# 246     MAA001867   3_39_F  Trachea       NaN       Multiple         F
#
# [247 rows x 6 columns]

# %%
# create an heart metadata table
heart_metadata=metadata[metadata['tissue']=="Heart"]
print(heart_metadata.head(10))
# Out:
#     plate.barcode mouse.id tissue subtissue FACS.selection mouse.sex
# 109     MAA000398    3_9_M  Heart        LA         Viable         M
# 110     MAA000399    3_9_M  Heart        RV         Viable         M
# 111     MAA000400    3_8_M  Heart        LA         Viable         M
# 112     MAA000452    3_8_M  Heart        RV         Viable         M
# 113     MAA000586    3_8_M  Heart        RA         Viable         M
# 114     MAA000587    3_8_M  Heart        LV         Viable         M
# 115     MAA000589    3_9_M  Heart        LV         Viable         M
# 116     MAA000594    3_8_M  Heart     Aorta         Viable         M
# 117     MAA000595    3_9_M  Heart     Aorta         Viable         M
# 118     MAA000898   3_11_M  Heart        RV         Viable         M
